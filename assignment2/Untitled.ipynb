# %%
# !python q1_softmax.py
# Out:
# 2017-11-06 12:48:39.076116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Found device 0 with properties:
# name: GeForce GTX TITAN X major: 5 minor: 2 memoryClockRate(GHz): 1.076
# pciBusID: 0000:81:00.0
# totalMemory: 11.92GiB freeMemory: 11.81GiB
# 2017-11-06 12:48:39.076214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1055] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: GeForce GTX TITAN X, pci bus id: 0000:81:00.0, compute capability: 5.2)
# Softmax test 1 passed!
# 2017-11-06 12:48:39.101447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1055] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: GeForce GTX TITAN X, pci bus id: 0000:81:00.0, compute capability: 5.2)
# Softmax test 2 passed!
# Basic (non-exhaustive) softmax tests pass
#
# ...

# %%
# !python q1_classifier.py
# Out:
# 2017-11-07 02:52:24.239409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Found device 0 with properties:
# name: GeForce GTX TITAN X major: 5 minor: 2 memoryClockRate(GHz): 1.076
# pciBusID: 0000:81:00.0
# totalMemory: 11.92GiB freeMemory: 11.81GiB
# 2017-11-07 02:52:24.239506: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1055] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: GeForce GTX TITAN X, pci bus id: 0000:81:00.0, compute capability: 5.2)
# Epoch 0: loss = 59.18 (0.348 sec)
# Epoch 1: loss = 20.32 (0.026 sec)
# Epoch 2: loss = 10.92 (0.025 sec)
# Epoch 3: loss = 7.30 (0.021 sec)
# Epoch 4: loss = 5.44 (0.024 sec)
# Epoch 5: loss = 4.32 (0.022 sec)
# Epoch 6: loss = 3.58 (0.024 sec)
# Epoch 7: loss = 3.05 (0.023 sec)
# Epoch 8: loss = 2.65 (0.030 sec)
# Epoch 9: loss = 2.35 (0.024 sec)
# Epoch 10: loss = 2.11 (0.023 sec)
# Epoch 11: loss = 1.91 (0.023 sec)
# Epoch 12: loss = 1.75 (0.022 sec)
# Epoch 13: loss = 1.61 (0.023 sec)
# ...

# %%
# !python q2_parser_transitions.py
# Out:
# SHIFT test passed!
# LEFT-ARC test passed!
# RIGHT-ARC test passed!
# parse test passed!
# minibatch_parse test passed!

# %%
# !python q2_parser_model.py
# Out:
# ...
# INITIALIZING
# ...
# Loading data... took 4.21 seconds
# Building parser... took 2.02 seconds
# Loading pretrained embeddings... took 4.97 seconds
# Vectorizing data... took 2.60 seconds
# Preprocessing training data...
# 39832/39832 [==============================] - 79s
# Building model... took 0.37 seconds
#
# 2017-11-25 15:55:54.869376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Found device 0 with properties:
# name: GeForce GTX TITAN X major: 5 minor: 2 memoryClockRate(GHz): 1.076
# pciBusID: 0000:81:00.0
# totalMemory: 11.92GiB freeMemory: 11.81GiB
# 2017-11-25 15:55:54.869479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1055] Creating TensorFlow device (/device:GPU:0) -> (device: 0, name: GeForce GTX TITAN X, pci bus id: 0000:81:00.0, compute capability: 5.2)
# ...
# TRAINING
# ...
# Epoch 1 out of 10
# 924/924 [==============================] - 19s - train loss: 0.1996
# Evaluating on dev set - dev UAS: 83.81
# ...
